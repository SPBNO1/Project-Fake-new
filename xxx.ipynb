# %%
# !pip install pythainlp
# !pip install full
# !pip install emoji
# !pip install attacut
import pandas as pd

# %%
df_fake = pd.read_csv("data/fake.csv")
df_real = pd.read_csv("data/real.csv")

# %%
df_real
df_fake["class"] = 0
df_real["class"] = 1
df_merge = pd.concat([df_fake, df_real], axis =0 )
df_merge.head(10)
df=df_merge.drop(["title", "type","url","W/D/Y","summary",], axis = 1)
import pythainlp
from pythainlp.corpus import thai_stopwords
from pythainlp.tokenize import word_tokenize
import re
import string
from pythainlp.util import normalize
from pythainlp.tokenize import newmm
def cleanText(sentences): 
 text = []
 temp = []
 for txt in sentences:
    t = str(txt)                                                                  # แปลงข้อความเป็น string เพื่อให้แน่ใจว่าเป็นข้อความ
    text = re.sub('[^ก-๙]','',txt)                                                   # ลบตัวอักษรที่ไม่ใช่ภาษาไทย
    text = normalize(txt)
    stop_word = list(thai_stopwords())                                                # ดึง stopwords ภาษาไทย
    sentence = word_tokenize(text, engine="newmm", keep_whitespace=False)             # ตัดคำ
    result = [word for word in sentence if word not in stop_word and " " not in word]
    temp.append([i.lower() for i in sentence])
    text.append(" ".join(result,sentence).lower())
    return text , temp
def cleanText(sentences):
    text = []
    temp = []
    for txt in sentences:
        # แปลงเป็น string
        t = str(txt)

        # ลบตัวอักษรที่ไม่ใช่ภาษาไทย
        cleaned_text = re.sub('[^ก-๙]', '', t)

        # Normalize ข้อความ
        normalized_text = normalize(cleaned_text)

        # ดึง stopwords ภาษาไทย
        stop_words = list(thai_stopwords())

        # ตัดคำ
        words = word_tokenize(normalized_text, engine="newmm")

        # ลบ stopwords และคำที่มีช่องว่าง
        filtered_words = [word for word in words if word not in stop_words and " " not in word]

        # แปลงเป็น lowercase และรวมคำ
        cleaned_sentence = " ".join(filtered_words).lower()

        # เก็บผลลัพธ์
        text.append(cleaned_sentence)
        temp.append([word.lower() for word in words])

    return text, temp
l = df.body
cleaned_word , temp = cleanText(l)
len(cleaned_word)
cleaned_word[:5]
# Out:
# ['ผู้พบเห็น เว็บไซต์ ธนาคารออมสิน ปล่อย สินเชื่อ ส่วนบุคคล ศูนย์ ต่อต้าน ข่าว ปลอม ดำเนินการ ตรวจสอบ ข้อเท็จจริง ธนาคารออมสิน กระทรวงการคลัง ประเด็น ข้อมูล เท็จ กรณี เว็บไซต์ ธนาคารออมสิน ปล่อย สินเชื่อ ส่วนบุคคล ธนาคารออมสิน กระทรวงการคลัง ตรวจสอบ ข้อมูล ชี้แจง เว็บไซต์ ธนาคารออมสิน ธนาคาร มีส่วน เผยแพร่ ข้อมูล ปล่อย สินเชื่อ ธนาคารออมสิน นโยบาย เงินกู้ เฟซบุ๊ก แอปพลิเคชัน ไลน์ เว็บไซต์ แอบอ้าง ชื่อ ตรา สัญลักษณ์ ธนาคารออมสิน ทำ รูป โปรไฟล์ ได้รับอนุญาต เผยแพร่ ข้อมูล ความเป็นจริง แสดงเจตนา จงใจ หลอกลวง ประชาชน กระทบ ชื่อเสียง ภาพลักษณ์ ธนาคาร ดำเนินการ เอาผิด ทางกฎหมาย ต่อไป ธนาคาร แจ้ง ประชาชน พบเห็น เว็บไซต์ สื่อ ออนไลน์ ชื่อ โลโก้ ชื่อ ผลิตภัณฑ์ สี อัตลักษณ์ ธนาคารออมสิน โปรไฟล์ โพสต์ เชิญชวน กู้เงิน ลักษณะ สื่อ ข้อมูล ปลอม หลอก โอน เงิน โปรด หลักฐาน สนทนา ลิงก์ ไลน์ ชื่อ หมายเลข โทรศัพท์ โอน เงิน เลขที่ บัญชี ธนาคาร ปลายทาง แจ้ง ศูนย์ แจ้งเหตุ ภัย มิจฉาชีพ ทางการเงิน โทร กด แจ้งความ ร้องทุกข์ เจ้าหน้าที่ตำรวจ ท้องที่ เจ้าหน้าที่ตำรวจ ประสานงาน ธนาคาร ระงับ ความเสียหาย โดยเร็ว',
# ...

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer

def cre_tokenizer(text, filters=''):
    tok = Tokenizer(filters=filters)
    tok.fit_on_texts(text)
    return tok

# %%
df.body
# Out:
# 0      ตามที่มีผู้พบเห็นเว็บไซต์ www.gsb-th-online.co...
# 1      ตามที่มีคลิปวิดีโอได้เผยแพร่เนื้อหา เกี่ยวกับป...
# 2      ตามที่มีการเผยแพร่ข่าวสารในสื่อออนไลน์เรื่อง เ...
# 3      เมื่อวันที่ 27 เมษายน สำนักงานคณะกรรมการการเลื...
# 4      จากกรณีข่าวลือที่ระบุว่าผู้ว่าจังหวัดภูเก็ตเหม...
#                              ...
# 500    องค์การขนส่งมวลชนกรุงเทพ (ขสมก.) อำนวยความสะดว...
# 501    เมื่อ 14 กรกฎาคม 2563 ที่ประชุมคณะรัฐมนตรี  มี...
# 502    ผู้ว่าราชการกรุงเทพมหานคร เปิดเผยว่า เนื่องในว...
# 503    นายกฯ สั่งแบล็คลิสต์โรงแรมที่ฉวยโอกาสขึ้นราคาจ...
# 504    เนื่องด้วยวันที่ 28 กรกฎาคมของทุกปี เป็นวันเฉล...
# Name: body, Length: 813, dtype: object

# %%
# #uncomment if you are running from google colab
# !pip install sklearn_crfsuite
# !pip install https://github.com/PyThaiNLP/pythainlp/archive/dev.zip
# !pip install fastai==1.0.45
# !wget https://github.com/wongnai/wongnai-corpus/raw/master/review/review_dataset.zip; unzip review_dataset.zip
# !mkdir wongnai_data; ls
# Out:
# ...
#   Using cached https://github.com/PyThaiNLP/pythainlp/archive/dev.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import fastai
print(fastai.__version__)
# Out:
# 2.7.17

# %%
pip install --upgrade fastai
# Out:
# ...
# ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip uninstall fastai
# !pip install fastai
# Out:
# Found existing installation: fastai 2.7.17
# Uninstalling fastai-2.7.17:
#   Would remove:
#     /opt/conda/bin/configure_accelerate
#     /opt/conda/lib/python3.11/site-packages/fastai-2.7.17.dist-info/*
#     /opt/conda/lib/python3.11/site-packages/fastai/*
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user
# ...

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from tqdm.notebook import tqdm
from collections import Counter
import re
import matplotlib.pyplot as plt
import seaborn as sns

from fastai.text.all import *  # Import all from fastai.text (v2)
from fastai.callback.tracker import CSVLogger  # Import CSVLogger from the correct module

from pythainlp.ulmfit import *

model_path = "wongnai_data/"

# %%
# If you want to include the original body text as well:
cleaned_df = pd.DataFrame({
    'cleaned_text': cleaned_word  # cleaned text
})
cleaned_df.to_csv('cleaned_text_data.csv', index=False, encoding='utf-8-sig')

# %%
train_df = pd.read_csv("cleaned_text_data.csv")
train_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 cleaned_text
# ...

# %%
import pandas as pd

# Load the two CSV files
df1 = pd.read_csv('cleaned_text_data.csv')  # This has 'id' and 'name'
df2 = pd.read_csv('merged_data.csv')  # This has 'id' and 'age'

# Merge the DataFrames on the 'id' column
combined_df = pd.merge(df1, df2, on='cleaned_text', how='left')  # Use 'outer' if you want all records

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('combined_file.csv', index=False)

# Display the combined DataFrame
print(combined_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_161/2055147777.py in ?()
#       4 df1 = pd.read_csv('cleaned_text_data.csv')  # This has 'id' and 'name'
#       5 df2 = pd.read_csv('merged_data.csv')  # This has 'id' and 'age'
#       6
#       7 # Merge the DataFrames on the 'id' column
# ----> 8 combined_df = pd.merge(df1, df2, on='cleaned_text', how='left')  # Use 'outer' if you want all records
#       9
#      10 # Save the combined DataFrame to a new CSV file
#      11 combined_df.to_csv('combined_file.csv', index=False)
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
# ...

# %%
import pandas as pd

# Load the two CSV files
df1 = pd.read_csv('cleaned_text_data.csv')  # Check what columns are here
df2 = pd.read_csv('merged_data.csv')  # Check what columns are here

# Print column names for both DataFrames
print("Columns in df1:")
print(df1.columns)

print("\nColumns in df2:")
print(df2.columns)
# Out:
# Columns in df1:
# Index(['cleaned_text'], dtype='object')
#
# Columns in df2:
# Index(['title', 'body', 'type', 'W/D/Y', 'url', 'class', 'summary', 'year'], dtype='object')

# %%
import pandas as pd

# Assuming file2.csv only has the 'age' column and same order as file1
df11['cleaned_text'] = pd.read_csv('cleaned_text_data.csv')['cleaned_text']

# Save the updated DataFrame to a new CSV file
df11.to_csv('merged_data.csv', index=False)

# %%
df11
# Out:
#                                                                                             title  \
# 0           ข่าวปลอม อย่าแชร์! เว็บไซต์ www.gsb-th-online.com ธนาคารออมสิน ปล่อยสินเชื่อส่วนบุคคล
# 1    ข่าวปลอม อย่าแชร์! ดร.เศรษฐพุฒิ สุทธิวาทนฤพุฒิ ผู้ว่าการแบงก์ชาติ ให้ความเห็นวิจารณ์การเมือง
# 2                       เอกสารแถลงการณ์ของสถานทูตเมียนมาร์ในประเทศไทย \nต่อเหตุการณ์ชุมนุมประท้วง
# 3             ‘กกต.’ แจงวุ่นเฟคนิวส์ หมายเลข ‘เพื่อไทย-ก้าวไกล’ ในคู่มือเลือกตั้งหาย ขู่ดำเนินคดี
# 4                     ข่าวปลอม! มีการลักลอบนำชาวมุสลิมต่างด้าวเข้าภูเก็ต\n ในเวลากลางคืนด้วยรถตู้
# ..                                                                                            ...
# 815                      ขสมก. เปิดลงทะเบียนบัตรโดยสารผ่านเว็บไซต์ แตะสแกนเช็คอิน-เช็คเอาท์ไทยชนะ
# 816                                   ครม. อนุมัติใช้มอเตอร์เวย์ 2 สายฟรี ตั้งแต่ 24 – 29 ก.ค. 63
# ...

# %%
df_ = pd.concat([df_fake, df_real], axis=0)
df_merge.to_csv('merged_data.csv', index=False, encoding='utf-8-sig')

# %%
df11.head()
# Out:
#                                                                                           title  \
# 0         ข่าวปลอม อย่าแชร์! เว็บไซต์ www.gsb-th-online.com ธนาคารออมสิน ปล่อยสินเชื่อส่วนบุคคล
# 1  ข่าวปลอม อย่าแชร์! ดร.เศรษฐพุฒิ สุทธิวาทนฤพุฒิ ผู้ว่าการแบงก์ชาติ ให้ความเห็นวิจารณ์การเมือง
# 2                     เอกสารแถลงการณ์ของสถานทูตเมียนมาร์ในประเทศไทย \nต่อเหตุการณ์ชุมนุมประท้วง
# 3           ‘กกต.’ แจงวุ่นเฟคนิวส์ หมายเลข ‘เพื่อไทย-ก้าวไกล’ ในคู่มือเลือกตั้งหาย ขู่ดำเนินคดี
# 4                   ข่าวปลอม! มีการลักลอบนำชาวมุสลิมต่างด้าวเข้าภูเก็ต\n ในเวลากลางคืนด้วยรถตู้
#
# ...

# %%
tt = Tokenizer(tok_func=ThaiTokenizer, lang="th", pre_rule =pre_rules_th, post_rules=post_rules_th)
processor = [TokenizeProcessor(tokenizer=tt, chunksize=10000, mark_fields=False),
            NumericalizeProcessor(vocab=data_lm.vocab, max_vocab=60000, min_freq=3)]

data_cls = (TextList.from_df(train_bal, model_path, cols=["cleaned_text"], processor=processor)
    .random_split_by_pct(valid_pct = 0.01, seed = 1412)
    .label_from_df("class")
    .add_test(TextList.from_df(test_df, model_path, cols=["cleaned_text"], processor=processor))
    .databunch(bs=32)
    )

data_cls.sanity_check()
data_cls.save("wongnai_cls.pkl")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 tt = Tokenizer(tok_func=ThaiTokenizer, lang="th", pre_rule =pre_rules_th, post_rules=post_rules_th)
#       2 processor = [TokenizeProcessor(tokenizer=tt, chunksize=10000, mark_fields=False),
#       3             NumericalizeProcessor(vocab=data_lm.vocab, max_vocab=60000, min_freq=3)]
#       5 data_cls = (TextList.from_df(train_bal, model_path, cols=["cleaned_text"], processor=processor)
#       6     .random_split_by_pct(valid_pct = 0.01, seed = 1412)
#       7     .label_from_df("class")
#       8     .add_test(TextList.from_df(test_df, model_path, cols=["cleaned_text"], processor=processor))
#       9     .databunch(bs=32)
#      10     )
#
# File /opt/conda/lib/python3.11/site-packages/fastcore/transform.py:43, in _TfmMeta.__call__(cls, *args, **kwargs)
#      41     getattr(cls,n).add(f)
# ...

# %%
#process data
train_df = pd.read_csv("merged_data.csv", sep=";", header=None).drop_duplicates()
train_df.columns = ["cleaned_text"]
# test_df = pd.read_csv("test_file.csv", sep=";")
# test_df["class"] = 0
train_df["class"] = 0
all_df = pd.concat([pd.DataFrame(test_df["class"]),\
                   pd.DataFrame(train_df["class"])]).reset_index(drop=True)
two_df = pd.concat([train_df[train_df.rating==0].copy() for i in range(2)]).reset_index(drop=True)
one_df = pd.concat([train_df[train_df.rating==1].copy() for i in range(10)]).reset_index(drop=True)
train_bal = pd.concat([train_df, one_df, two_df]).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[49], line 2
#       1 #process data
# ----> 2 train_df = pd.read_csv("merged_data.csv", sep=";", header=None).drop_duplicates()
#       3 train_df.columns = ["cleaned_text"]
#       4 # test_df = pd.read_csv("test_file.csv", sep=";")
#       5 # test_df["class"] = 0
#
# ...

# %%
# !pip install jupyterlab-git

# %%
# !jupyter labextension install @jupyterlab/git
# Out:
# (Deprecated) Installing extensions with the jupyter labextension install command is now deprecated and will be removed in a future major version of JupyterLab.
#
# Users should manage prebuilt extensions with package managers like pip and conda, and extension authors are encouraged to distribute their extensions as prebuilt packages
# Building jupyterlab assets (production, minimized)
# The extension "nbdime-jupyterlab" is outdated.

# %%
# !git clone https://github.com/SPBNO1/Project-Fake-new.git
# Out:
# Cloning into 'Project-Fake-new'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 55.05 KiB | 599.00 KiB/s, done.

# %%
# !ls
# Out:
# all_df.csv	       test_file.csv
# cleaned_text_data.csv  test.ipynb
# data		       testpro
# datatest	       thai_text_classification_model.bin
# df_drop.csv	       thsarabunnew-webfont.ttf
# __MACOSX	       thsarabunnew-webfont.ttf.1
# manual_testing.csv     thsarabunnew-webfont.ttf.2
# master.zip	       thsarabunnew-webfont.ttf.3
# master.zip.1	       thsarabunnew-webfont.ttf.4
# master.zip.2	       thsarabunnew-webfont.ttf.5
# merged_data.csv        thsarabunnew-webfont.ttf.6
# model.ipynb	       thsarabunnew-webfont.ttf.7
# prepare.ipynb	       train.txt
# Project-Fake-new       wisesight_data
# project.ipynb	       wisesight-sentiment-master
# review_dataset.zip     wongnai_data
# review_dataset.zip.1   w_review_train.csv
# sample_submission.csv  xxx.ipynb
# test
